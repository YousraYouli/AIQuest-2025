# %%
import os
from PIL import Image
from pyzbar.pyzbar import decode
import re
import json
import requests
import random

class ReinforcementLearningAgent:
    def __init__(self, actions=["Frauduleux", "Suspect", "Sûr"]):
        self.actions = actions  # Actions possibles
        self.q_table = {}  # Q-table (table de Q-learning)
        self.alpha = 0.1  # Taux d'apprentissage
        self.gamma = 0.9  # Facteur de discount
        self.epsilon = 0.1  # Taux d'exploration (10% exploration, 90% exploitation)

    def get_action(self, state):
        """Choisit une action en fonction de l'exploration et de l'exploitation."""
        if random.uniform(0, 1) < self.epsilon:
            return random.choice(self.actions)  # Exploration
        else:
            return self.max_action(state)  # Exploitation

    def max_action(self, state):
        """Retourne l'action avec la valeur maximale dans la Q-table."""
        if state not in self.q_table:
            self.q_table[state] = {action: 0 for action in self.actions}
        max_action = max(self.q_table[state], key=self.q_table[state].get)
        return max_action

    def update_q_table(self, state, action, reward, next_state):
        """Met à jour la Q-table en fonction de l'agent et des récompenses."""
        if state not in self.q_table:
            self.q_table[state] = {action: 0 for action in self.actions}

        if next_state not in self.q_table:
            self.q_table[next_state] = {action: 0 for action in self.actions}

        # Q-learning update rule
        best_next_action = self.max_action(next_state)
        self.q_table[state][action] = self.q_table[state][action] + self.alpha * (
            reward + self.gamma * self.q_table[next_state][best_next_action] - self.q_table[state][action]
        )

    def save_model(self, file_path):
        """Enregistre le modèle (Q-table) dans un fichier JSON."""
        with open(file_path, 'w') as file:
            json.dump(self.q_table, file, indent=4)
        print(f"Modèle sauvegardé dans {file_path}")

    def load_model(self, file_path):
        """Charge le modèle (Q-table) à partir d'un fichier JSON."""
        try:
            with open(file_path, 'r') as file:
                self.q_table = json.load(file)
            print(f"Modèle chargé depuis {file_path}")
        except FileNotFoundError:
            print(f"Fichier {file_path} non trouvé. Un nouveau modèle sera utilisé.")

def extract_qr_code_data(image_path):
    try:
        image = Image.open(image_path)
        decoded_data = decode(image)
        if decoded_data:
            return [obj.data.decode('utf-8').strip() for obj in decoded_data]
        else:
            return []
    except Exception as e:
        print(f"Erreur lors de l'ouverture ou du traitement de l'image : {e}")
        return []

def classify_qr_data(agent, data):
    score = 0
    state = data  # L'état est basé sur les données QR extraites

    # Vérifier si c'est une URL
    if re.match(r'https?://[^\s]+', data):
        score += analyze_url(data)
        action = agent.get_action(state)
        if score >= 7:
            reward = -10 if action != "Frauduleux" else 10  # Récompense négative pour mauvaise classification
        else:
            reward = 10 if action == "Sûr" else -10  # Récompense positive pour bonne classification

    # Vérifier si c'est un email
    elif re.match(r"[^@]+@[^@]+\.[^@]+", data):
        score += analyze_email(data)
        action = agent.get_action(state)
        if score >= 3:
            reward = -10 if action != "Frauduleux" else 10
        else:
            reward = 10 if action == "Sûr" else -10

    # Vérifier si c'est un numéro de téléphone
    elif re.match(r"^\+?[0-9]{7,15}$", data):
        score += analyze_phone(data)
        action = agent.get_action(state)
        if score >= 2:
            reward = -10 if action != "Frauduleux" else 10
        else:
            reward = 10 if action == "Sûr" else -10

    # Vérifier si c'est un texte général
    else:
        score += analyze_text(data)
        action = agent.get_action(state)
        if score >= 2:
            reward = -10 if action != "Frauduleux" else 10
        else:
            reward = 10 if action == "Sûr" else -10

    agent.update_q_table(state, action, reward, state)  # Mettre à jour la table Q
    return action

def analyze_url(url):
    score = 0
    if not url.startswith("https://"):
        score += 1
    suspicious_keywords = ["login", "verify", "secure", "bank", "free", "money", "update", "password"]
    if any(kw in url.lower() for kw in suspicious_keywords):
        score += 2
    api_response = check_with_api(url)
    if api_response == "malicious":
        score += 5
    return score

def analyze_email(email):
    score = 0
    suspicious_domains = ["mailinator.com", "tempmail.com", "fake.com"]
    domain = email.split("@")[1]
    if domain in suspicious_domains:
        score += 3
    return score

def analyze_phone(phone):
    score = 0
    if not phone.startswith("+") or len(phone) < 10:
        score += 2
    return score

def analyze_text(text):
    score = 0
    if "http" in text:
        score += 2
    suspicious_keywords = ["urgent", "lottery", "password", "bank", "account", "secure"]
    if any(kw in text.lower() for kw in suspicious_keywords):
        score += 2
    if len(text) > 200:
        score += 1
    return score

def check_with_api(data):
    response = requests.get(f"https://api.example.com/analyze?data={data}")
    if response.status_code == 200:
        result = response.json()
        return result.get("status", "unknown")
    return "unknown"

folder_path = r"Multi-version QR codes dataset\qr_codes"
agent = ReinforcementLearningAgent()
model_path = "q_learning_model.json"

# Charger le modèle si disponible
agent.load_model(model_path)

for filename in os.listdir(folder_path):
    image_path = os.path.join(folder_path, filename)
    print("*****************************")
    print(image_path)
    mylistResult = []
    try:
        decoded_data = extract_qr_code_data(image_path)
        if decoded_data:
            print(f"Les données décodées sont {decoded_data}")
            for elem in decoded_data:
                mylistResult.append(classify_qr_data(agent, elem))
            print(f"Liste des résultats : {mylistResult}")
            if "Frauduleux" in mylistResult:
                print("Fraud")
            else:
                print("Normal QR")
        else:
            print("Aucun QR code valide détecté.")
    except Exception as e:
        print(f"Erreur lors de l'ouverture de l'image : {e}")

# Sauvegarder le modèle à la fin
agent.save_model(model_path)
# Out:
# Fichier q_learning_model.json non trouvé. Un nouveau modèle sera utilisé.
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_10_100000.png
# Les données décodées sont ['100000    https://www.akpsi.org/donations/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_10_100001.png
# Les données décodées sont ['100001    https://www.akripol.si/en/mreza/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_10_100002.png
# Les données décodées sont ['100002    https://www.akripol.si/en/podjetje/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_10_100003.png
# Les données décodées sont ['100003    https://www.akrofire.com/MohawkWovenNylonCarpe...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_10_100004.png
# Les données décodées sont ['100004    https://www.akron.com/20060921/wsl57.asp\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_10_100005.png
# Les données décodées sont ['100005    https://www.akron.com/akron-ohio-entertainment...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_10_100006.png
# Les données décodées sont ['100006    https://www.akronartmuseum.org/exhibitions/det...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_10_100007.png
# Les données décodées sont ['100007    https://www.akrondesign.com/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_10_100008.png
# Les données décodées sont ['100008    https://www.akronohioonline.com/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_10_100009.png
# Les données décodées sont ['100009    https://www.akronohrealestate.info/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_10_100010.png
# Les données décodées sont ['100010    https://www.akshay-kumar-wallpapers.info/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_10_100011.png
# Les données décodées sont ['100011    https://www.akufen.ca/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_10_100012.png
# Les données décodées sont ['100012    https://www.akwarner.com/sade/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_10_100013.png
# Les données décodées sont ['100013    https://www.al-airliners.be/k-o/mohawk/mohawk.htm\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_10_100014.png
# Les données décodées sont ['100014    https://www.al-anon-montreal.org/H20reunionsan...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_10_100015.png
# Les données décodées sont ['100015    https://www.al-islam.org/beliefs/philosophy/op...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_10_100016.png
# Les données décodées sont ['100016    https://www.al.com/auburnbasketball/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_10_100017.png
# Les données décodées sont ['100017    https://www.al.com/birminghamnews/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_10_100018.png
# Les données décodées sont ['100018    https://www.al.com/entertainment/birmingham/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_10_100019.png
# Les données décodées sont ['100019    https://www.al.com/entertainment/index.ssf/200...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_10_100020.png
# Les données décodées sont ['100020    https://www.al.com/forums/music/index.ssf?arti...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_10_100021.png
# Les données décodées sont ['100021    https://www.al.com/news/birminghamnews/metro.s...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_10_100022.png
# Les données décodées sont ['100022    https://www.al.com/news/mobile/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_10_100023.png
# Les données décodées sont ['100023    https://www.al.com/newsflash/index.ssf/story/k...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_10_100024.png
# Les données décodées sont ['100024    https://www.al.com/sports/index.ssf/2011/02/as...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_10_100025.png
# Les données décodées sont ['100025    https://www.al.com/sports/index.ssf/2011/03/ja...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_10_100026.png
# Les données décodées sont ['100026    https://www.al.com/sports/index.ssf/2011/04/no...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_10_100027.png
# Les données décodées sont ['100027    https://www.al.com/sports/index.ssf/2011/05/di...\nName: url, dtype: object']
# Liste des résultats : ['Sûr']
# Normal QR
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_10_100028.png
# Les données décodées sont ['100028    https://www.al.com/sports/index.ssf/2011/07/na...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_10_100029.png
# Les données décodées sont ['100029    https://www.al.com/sports/index.ssf/2011/09/te...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_10_100030.png
# Les données décodées sont ['100030    https://www.al.com/sports/index.ssf/2011/11/es...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_10_100031.png
# Les données décodées sont ['100031    https://www.al.com/sports/index.ssf/2011/11/es...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_10_100032.png
# Les données décodées sont ['100032    https://www.al3d.net/ea_montreal.htm\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_10_100033.png
# Les données décodées sont ['100033    https://www.ala.org/Template.cfm?Section=award...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_10_100034.png
# Les données décodées sont ['100034    https://www.ala.org/ala/aboutala/missionhistor...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_10_100035.png
# Les données décodées sont ['100035    https://www.ala.org/ala/aboutala/offices/ppo/p...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_10_100036.png
# Les données décodées sont ['100036    https://www.ala.org/alsc/awardsgrants/bookmedi...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_10_100037.png
# Les données décodées sont ['100037    https://www.ala.org/alsc/awardsgrants/bookmedi...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_10_100038.png
# Les données décodées sont ['100038    https://www.alaa.se/work/yoopa/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_10_100039.png
# Les données décodées sont ['100039    https://www.alabamajapanesechinbreeders.com/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_10_100040.png
# Les données décodées sont ['100040    https://www.alabamarealestatecompanies.com/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_10_100041.png
# Les données décodées sont ['100041    https://www.alabamawx.com/?p=26076\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_10_100042.png
# Les données décodées sont ['100042    https://www.alacrastore.com/company-snapshot/A...\nName: url, dtype: object']
# Liste des résultats : ['Suspect']
# Normal QR
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_10_100043.png
# Les données décodées sont ['100043    https://www.alacrastore.com/company-snapshot/A...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_10_100044.png
# Les données décodées sont ['100044    https://www.alacrastore.com/company-snapshot/A...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_10_100045.png
# Les données décodées sont ['100045    https://www.alacrastore.com/company-snapshot/A...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_10_100046.png
# Les données décodées sont ['100046    https://www.alacrastore.com/company-snapshot/A...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_10_100047.png
# Les données décodées sont ['100047    https://www.alacrastore.com/company-snapshot/A...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_10_100048.png
# Les données décodées sont ['100048    https://www.alacrastore.com/company-snapshot/A...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_10_100049.png
# Les données décodées sont ['100049    https://www.alacrastore.com/company-snapshot/A...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_20_100000.png
# Les données décodées sont ['100000    https://www.akpsi.org/donations/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_20_100001.png
# Les données décodées sont ['100001    https://www.akripol.si/en/mreza/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_20_100002.png
# Les données décodées sont ['100002    https://www.akripol.si/en/podjetje/\nName: url, dtype: object']
# Liste des résultats : ['Sûr']
# Normal QR
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_20_100003.png
# Les données décodées sont ['100003    https://www.akrofire.com/MohawkWovenNylonCarpe...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_20_100004.png
# Les données décodées sont ['100004    https://www.akron.com/20060921/wsl57.asp\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_20_100005.png
# Les données décodées sont ['100005    https://www.akron.com/akron-ohio-entertainment...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_20_100006.png
# Les données décodées sont ['100006    https://www.akronartmuseum.org/exhibitions/det...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_20_100007.png
# Les données décodées sont ['100007    https://www.akrondesign.com/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_20_100008.png
# Les données décodées sont ['100008    https://www.akronohioonline.com/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_20_100009.png
# Les données décodées sont ['100009    https://www.akronohrealestate.info/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_20_100010.png
# Les données décodées sont ['100010    https://www.akshay-kumar-wallpapers.info/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_20_100011.png
# Les données décodées sont ['100011    https://www.akufen.ca/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_20_100012.png
# Les données décodées sont ['100012    https://www.akwarner.com/sade/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_20_100013.png
# Les données décodées sont ['100013    https://www.al-airliners.be/k-o/mohawk/mohawk.htm\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_20_100014.png
# Les données décodées sont ['100014    https://www.al-anon-montreal.org/H20reunionsan...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_20_100015.png
# Les données décodées sont ['100015    https://www.al-islam.org/beliefs/philosophy/op...\nName: url, dtype: object']
# Liste des résultats : ['Suspect']
# Normal QR
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_20_100016.png
# Les données décodées sont ['100016    https://www.al.com/auburnbasketball/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_20_100017.png
# Les données décodées sont ['100017    https://www.al.com/birminghamnews/\nName: url, dtype: object']
# Liste des résultats : ['Suspect']
# Normal QR
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_20_100018.png
# Les données décodées sont ['100018    https://www.al.com/entertainment/birmingham/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_20_100019.png
# Les données décodées sont ['100019    https://www.al.com/entertainment/index.ssf/200...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_20_100020.png
# Les données décodées sont ['100020    https://www.al.com/forums/music/index.ssf?arti...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_20_100021.png
# Les données décodées sont ['100021    https://www.al.com/news/birminghamnews/metro.s...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_20_100022.png
# Les données décodées sont ['100022    https://www.al.com/news/mobile/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_20_100023.png
# Les données décodées sont ['100023    https://www.al.com/newsflash/index.ssf/story/k...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_20_100024.png
# Les données décodées sont ['100024    https://www.al.com/sports/index.ssf/2011/02/as...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_20_100025.png
# Les données décodées sont ['100025    https://www.al.com/sports/index.ssf/2011/03/ja...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_20_100026.png
# Les données décodées sont ['100026    https://www.al.com/sports/index.ssf/2011/04/no...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_20_100027.png
# Les données décodées sont ['100027    https://www.al.com/sports/index.ssf/2011/05/di...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_20_100028.png
# Les données décodées sont ['100028    https://www.al.com/sports/index.ssf/2011/07/na...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_20_100029.png
# Les données décodées sont ['100029    https://www.al.com/sports/index.ssf/2011/09/te...\nName: url, dtype: object']
# Liste des résultats : ['Sûr']
# Normal QR
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_20_100030.png
# Les données décodées sont ['100030    https://www.al.com/sports/index.ssf/2011/11/es...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_20_100031.png
# Les données décodées sont ['100031    https://www.al.com/sports/index.ssf/2011/11/es...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_20_100032.png
# Les données décodées sont ['100032    https://www.al3d.net/ea_montreal.htm\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_20_100033.png
# Les données décodées sont ['100033    https://www.ala.org/Template.cfm?Section=award...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_20_100034.png
# Les données décodées sont ['100034    https://www.ala.org/ala/aboutala/missionhistor...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_20_100035.png
# Les données décodées sont ['100035    https://www.ala.org/ala/aboutala/offices/ppo/p...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_20_100036.png
# Les données décodées sont ['100036    https://www.ala.org/alsc/awardsgrants/bookmedi...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_20_100037.png
# Les données décodées sont ['100037    https://www.ala.org/alsc/awardsgrants/bookmedi...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_20_100038.png
# Les données décodées sont ['100038    https://www.alaa.se/work/yoopa/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_20_100039.png
# Les données décodées sont ['100039    https://www.alabamajapanesechinbreeders.com/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_20_100040.png
# Les données décodées sont ['100040    https://www.alabamarealestatecompanies.com/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_20_100041.png
# Les données décodées sont ['100041    https://www.alabamawx.com/?p=26076\nName: url, dtype: object']
# Liste des résultats : ['Sûr']
# Normal QR
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_20_100042.png
# Les données décodées sont ['100042    https://www.alacrastore.com/company-snapshot/A...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_20_100043.png
# Les données décodées sont ['100043    https://www.alacrastore.com/company-snapshot/A...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_20_100044.png
# Les données décodées sont ['100044    https://www.alacrastore.com/company-snapshot/A...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_20_100045.png
# Les données décodées sont ['100045    https://www.alacrastore.com/company-snapshot/A...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_20_100046.png
# Les données décodées sont ['100046    https://www.alacrastore.com/company-snapshot/A...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_20_100047.png
# Les données décodées sont ['100047    https://www.alacrastore.com/company-snapshot/A...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_20_100048.png
# Les données décodées sont ['100048    https://www.alacrastore.com/company-snapshot/A...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_20_100049.png
# Les données décodées sont ['100049    https://www.alacrastore.com/company-snapshot/A...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_2_100000.png
# Les données décodées sont ['100000    https://www.akpsi.org/donations/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_2_100001.png
# Les données décodées sont ['100001    https://www.akripol.si/en/mreza/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_2_100002.png
# Les données décodées sont ['100002    https://www.akripol.si/en/podjetje/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_2_100003.png
# Les données décodées sont ['100003    https://www.akrofire.com/MohawkWovenNylonCarpe...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_2_100004.png
# Les données décodées sont ['100004    https://www.akron.com/20060921/wsl57.asp\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_2_100005.png
# Les données décodées sont ['100005    https://www.akron.com/akron-ohio-entertainment...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_2_100006.png
# Les données décodées sont ['100006    https://www.akronartmuseum.org/exhibitions/det...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_2_100007.png
# Les données décodées sont ['100007    https://www.akrondesign.com/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_2_100008.png
# Les données décodées sont ['100008    https://www.akronohioonline.com/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_2_100009.png
# Les données décodées sont ['100009    https://www.akronohrealestate.info/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_2_100010.png
# Les données décodées sont ['100010    https://www.akshay-kumar-wallpapers.info/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_2_100011.png
# Les données décodées sont ['100011    https://www.akufen.ca/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_2_100012.png
# Les données décodées sont ['100012    https://www.akwarner.com/sade/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_2_100013.png
# Les données décodées sont ['100013    https://www.al-airliners.be/k-o/mohawk/mohawk.htm\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_2_100014.png
# Les données décodées sont ['100014    https://www.al-anon-montreal.org/H20reunionsan...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_2_100015.png
# Les données décodées sont ['100015    https://www.al-islam.org/beliefs/philosophy/op...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_2_100016.png
# Les données décodées sont ['100016    https://www.al.com/auburnbasketball/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_2_100017.png
# Les données décodées sont ['100017    https://www.al.com/birminghamnews/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_2_100018.png
# Les données décodées sont ['100018    https://www.al.com/entertainment/birmingham/\nName: url, dtype: object']
# Liste des résultats : ['Sûr']
# Normal QR
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_2_100019.png
# Les données décodées sont ['100019    https://www.al.com/entertainment/index.ssf/200...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_2_100020.png
# Les données décodées sont ['100020    https://www.al.com/forums/music/index.ssf?arti...\nName: url, dtype: object']
# Liste des résultats : ['Suspect']
# Normal QR
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_2_100021.png
# Les données décodées sont ['100021    https://www.al.com/news/birminghamnews/metro.s...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_2_100022.png
# Les données décodées sont ['100022    https://www.al.com/news/mobile/\nName: url, dtype: object']
# Liste des résultats : ['Sûr']
# Normal QR
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_2_100023.png
# Les données décodées sont ['100023    https://www.al.com/newsflash/index.ssf/story/k...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_2_100024.png
# Les données décodées sont ['100024    https://www.al.com/sports/index.ssf/2011/02/as...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_2_100025.png
# Les données décodées sont ['100025    https://www.al.com/sports/index.ssf/2011/03/ja...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_2_100026.png
# Les données décodées sont ['100026    https://www.al.com/sports/index.ssf/2011/04/no...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_2_100027.png
# Les données décodées sont ['100027    https://www.al.com/sports/index.ssf/2011/05/di...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_2_100028.png
# Les données décodées sont ['100028    https://www.al.com/sports/index.ssf/2011/07/na...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_2_100029.png
# Les données décodées sont ['100029    https://www.al.com/sports/index.ssf/2011/09/te...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_2_100030.png
# Les données décodées sont ['100030    https://www.al.com/sports/index.ssf/2011/11/es...\nName: url, dtype: object']
# Liste des résultats : ['Sûr']
# Normal QR
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_2_100031.png
# Les données décodées sont ['100031    https://www.al.com/sports/index.ssf/2011/11/es...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_2_100032.png
# Les données décodées sont ['100032    https://www.al3d.net/ea_montreal.htm\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_2_100033.png
# Les données décodées sont ['100033    https://www.ala.org/Template.cfm?Section=award...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_2_100034.png
# Les données décodées sont ['100034    https://www.ala.org/ala/aboutala/missionhistor...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_2_100035.png
# Les données décodées sont ['100035    https://www.ala.org/ala/aboutala/offices/ppo/p...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_2_100036.png
# Les données décodées sont ['100036    https://www.ala.org/alsc/awardsgrants/bookmedi...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_2_100037.png
# Les données décodées sont ['100037    https://www.ala.org/alsc/awardsgrants/bookmedi...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_2_100038.png
# Les données décodées sont ['100038    https://www.alaa.se/work/yoopa/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_2_100039.png
# Les données décodées sont ['100039    https://www.alabamajapanesechinbreeders.com/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_2_100040.png
# Les données décodées sont ['100040    https://www.alabamarealestatecompanies.com/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_2_100041.png
# Les données décodées sont ['100041    https://www.alabamawx.com/?p=26076\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_2_100042.png
# Les données décodées sont ['100042    https://www.alacrastore.com/company-snapshot/A...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_2_100043.png
# Les données décodées sont ['100043    https://www.alacrastore.com/company-snapshot/A...\nName: url, dtype: object']
# Liste des résultats : ['Sûr']
# Normal QR
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_2_100044.png
# Les données décodées sont ['100044    https://www.alacrastore.com/company-snapshot/A...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_2_100045.png
# Les données décodées sont ['100045    https://www.alacrastore.com/company-snapshot/A...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_2_100046.png
# Les données décodées sont ['100046    https://www.alacrastore.com/company-snapshot/A...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_2_100047.png
# Les données décodées sont ['100047    https://www.alacrastore.com/company-snapshot/A...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_2_100048.png
# Les données décodées sont ['100048    https://www.alacrastore.com/company-snapshot/A...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_2_100049.png
# Les données décodées sont ['100049    https://www.alacrastore.com/company-snapshot/A...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_30_100000.png
# Les données décodées sont ['100000    https://www.akpsi.org/donations/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_30_100001.png
# Les données décodées sont ['100001    https://www.akripol.si/en/mreza/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_30_100002.png
# Les données décodées sont ['100002    https://www.akripol.si/en/podjetje/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_30_100003.png
# Les données décodées sont ['100003    https://www.akrofire.com/MohawkWovenNylonCarpe...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_30_100004.png
# Les données décodées sont ['100004    https://www.akron.com/20060921/wsl57.asp\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_30_100005.png
# Les données décodées sont ['100005    https://www.akron.com/akron-ohio-entertainment...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_30_100006.png
# Les données décodées sont ['100006    https://www.akronartmuseum.org/exhibitions/det...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_30_100007.png
# Les données décodées sont ['100007    https://www.akrondesign.com/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_30_100008.png
# Les données décodées sont ['100008    https://www.akronohioonline.com/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_30_100009.png
# Les données décodées sont ['100009    https://www.akronohrealestate.info/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_30_100010.png
# Les données décodées sont ['100010    https://www.akshay-kumar-wallpapers.info/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_30_100011.png
# Les données décodées sont ['100011    https://www.akufen.ca/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_30_100012.png
# Les données décodées sont ['100012    https://www.akwarner.com/sade/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_30_100013.png
# Les données décodées sont ['100013    https://www.al-airliners.be/k-o/mohawk/mohawk.htm\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_30_100014.png
# Les données décodées sont ['100014    https://www.al-anon-montreal.org/H20reunionsan...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_30_100015.png
# Les données décodées sont ['100015    https://www.al-islam.org/beliefs/philosophy/op...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_30_100016.png
# Les données décodées sont ['100016    https://www.al.com/auburnbasketball/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_30_100017.png
# Les données décodées sont ['100017    https://www.al.com/birminghamnews/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_30_100018.png
# Les données décodées sont ['100018    https://www.al.com/entertainment/birmingham/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_30_100019.png
# Les données décodées sont ['100019    https://www.al.com/entertainment/index.ssf/200...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_30_100020.png
# Les données décodées sont ['100020    https://www.al.com/forums/music/index.ssf?arti...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_30_100021.png
# Les données décodées sont ['100021    https://www.al.com/news/birminghamnews/metro.s...\nName: url, dtype: object']
# Liste des résultats : ['Sûr']
# Normal QR
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_30_100022.png
# Les données décodées sont ['100022    https://www.al.com/news/mobile/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_30_100023.png
# Les données décodées sont ['100023    https://www.al.com/newsflash/index.ssf/story/k...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_30_100024.png
# Les données décodées sont ['100024    https://www.al.com/sports/index.ssf/2011/02/as...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_30_100025.png
# Les données décodées sont ['100025    https://www.al.com/sports/index.ssf/2011/03/ja...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_30_100026.png
# Les données décodées sont ['100026    https://www.al.com/sports/index.ssf/2011/04/no...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_30_100027.png
# Les données décodées sont ['100027    https://www.al.com/sports/index.ssf/2011/05/di...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_30_100028.png
# Les données décodées sont ['100028    https://www.al.com/sports/index.ssf/2011/07/na...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_30_100029.png
# Les données décodées sont ['100029    https://www.al.com/sports/index.ssf/2011/09/te...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_30_100030.png
# Les données décodées sont ['100030    https://www.al.com/sports/index.ssf/2011/11/es...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_30_100031.png
# Les données décodées sont ['100031    https://www.al.com/sports/index.ssf/2011/11/es...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_30_100032.png
# Les données décodées sont ['100032    https://www.al3d.net/ea_montreal.htm\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_30_100033.png
# Les données décodées sont ['100033    https://www.ala.org/Template.cfm?Section=award...\nName: url, dtype: object']
# Liste des résultats : ['Sûr']
# Normal QR
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_30_100034.png
# Les données décodées sont ['100034    https://www.ala.org/ala/aboutala/missionhistor...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_30_100035.png
# Les données décodées sont ['100035    https://www.ala.org/ala/aboutala/offices/ppo/p...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_30_100036.png
# Les données décodées sont ['100036    https://www.ala.org/alsc/awardsgrants/bookmedi...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_30_100037.png
# Les données décodées sont ['100037    https://www.ala.org/alsc/awardsgrants/bookmedi...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_30_100038.png
# Les données décodées sont ['100038    https://www.alaa.se/work/yoopa/\nName: url, dtype: object']
# Liste des résultats : ['Suspect']
# Normal QR
# *****************************
# Multi-version QR codes dataset\qr_codes\benign_version_30_100039.png
# Les données décodées sont ['100039    https://www.alabamajapanesechinbreeders.com/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# ...
# Les données décodées sont ['416291    https://www.mailing027.gq/ib.absa.x/passcode_v...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\malicious_version_6_416292.png
# Les données décodées sont ['416292    https://secure.runescape.com-l.cz/m=weblogin/l...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\malicious_version_6_416293.png
# Les données décodées sont ['416293    https://serviceguru.in/interessa/HT65T/index.php\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\malicious_version_6_416294.png
# Les données décodées sont ['416294    https://review.cubicfrogapps.com/.well-known/a...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\malicious_version_6_416295.png
# Les données décodées sont ['416295    https://www.mailing027.cf/ib.absa/iAwIj4NCgkJC...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\malicious_version_6_416296.png
# Les données décodées sont ['416296    http://coreses.000webhostapp.com/scures.htm\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\malicious_version_6_416297.png
# Les données décodées sont ['416297    http://www.directregelen.org/abn%20amro/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\malicious_version_6_416298.png
# Les données décodées sont ['416298    http://www.mydocomo-smt-contact.com/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\malicious_version_6_416299.png
# Les données décodées sont ['416299    https://abacubic.com/.logs/details/www.america...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\malicious_version_6_416300.png
# Les données décodées sont ['416300    https://umarbgs.com/support/b9e5569b4ac4e89ce9...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\malicious_version_6_416301.png
# Les données décodées sont ['416301    http://www.vub360.net/verify.htm\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\malicious_version_6_416302.png
# Les données décodées sont ['416302    http://bbva-movil-r.com/Cliente/Alertas/ES1394...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\malicious_version_6_416303.png
# Les données décodées sont ['416303    http://thompsonsquare.ca/wp-includes/js/jquery...\nName: url, dtype: object']
# Liste des résultats : ['Sûr']
# Normal QR
# *****************************
# Multi-version QR codes dataset\qr_codes\malicious_version_7_416254.png
# Les données décodées sont ['416254    http://patelmunaf.com/adobe/adobe/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\malicious_version_7_416255.png
# Les données décodées sont ['416255    http://outersansai.id/443/www/login/sign-in/si...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\malicious_version_7_416256.png
# Les données décodées sont ['416256    http://atrading.akid.website/wp-admin/css/colo...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\malicious_version_7_416257.png
# Les données décodées sont ['416257    http://sdn04kaligelang.sch.id/css/home/2a49c42...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\malicious_version_7_416258.png
# Les données décodées sont ['416258    https://tiendavirtual.mytexcon.com/wp-admin/cs...\nName: url, dtype: object']
# Liste des résultats : ['Suspect']
# Normal QR
# *****************************
# Multi-version QR codes dataset\qr_codes\malicious_version_7_416259.png
# Les données décodées sont ['416259    https://tiendavirtual.mytexcon.com/wp-admin/cs...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\malicious_version_7_416260.png
# Les données décodées sont ['416260    http://islapartmentandhotel.com/www.paypal.com...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\malicious_version_7_416261.png
# Les données décodées sont ['416261    http://jeeyoonfoodservices.com/chrikiista.php\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\malicious_version_7_416262.png
# Les données décodées sont ['416262    http://scotts.co.place/wp-content/themes/baalh...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\malicious_version_7_416263.png
# Les données décodées sont ['416263    http://islapartmentandhotel.com/www.paypal.com...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\malicious_version_7_416264.png
# Les données décodées sont ['416264    http://locasiga.com.br/wp-content/signin/custo...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\malicious_version_7_416265.png
# Les données décodées sont ['416265    http://locasiga.com.br/wp-content/signin/custo...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\malicious_version_7_416266.png
# Les données décodées sont ['416266    http://papush.net/sites/default/files/freret/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\malicious_version_7_416267.png
# Les données décodées sont ['416267    http://banco-nacion-ar.online/idconnection8938...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\malicious_version_7_416268.png
# Les données décodées sont ['416268    http://banco-nacion-ar.online/idconnection8938...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\malicious_version_7_416269.png
# Les données décodées sont ['416269    http://bestchanle.net.ru/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\malicious_version_7_416270.png
# Les données décodées sont ['416270    https://mlscores.000webhostapp.com/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\malicious_version_7_416271.png
# Les données décodées sont ['416271    https://sites.google.com/view/newrecovery-help/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\malicious_version_7_416272.png
# Les données décodées sont ['416272    http://protect-users.esy.es/facebook-confirm\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\malicious_version_7_416273.png
# Les données décodées sont ['416273    http://protect-users.esy.es/facebook/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\malicious_version_7_416274.png
# Les données décodées sont ['416274    http://badwolfvape.com/cgi/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\malicious_version_7_416275.png
# Les données décodées sont ['416275    http://bestchanke.pp.ru/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\malicious_version_7_416276.png
# Les données décodées sont ['416276    http://papaaaor.beget.tech\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\malicious_version_7_416277.png
# Les données décodées sont ['416277    http://trep456.beget.tech\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\malicious_version_7_416278.png
# Les données décodées sont ['416278    https://philharmonic-cheek.000webhostapp.com/v...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\malicious_version_7_416279.png
# Les données décodées sont ['416279    https://sites.google.com/site/aporsconfrimpages/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\malicious_version_7_416280.png
# Les données décodées sont ['416280    https://goo.gl/qnbaeN\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\malicious_version_7_416281.png
# Les données décodées sont ['416281    https://appleid.apple.com-support.rasahsepanen...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\malicious_version_7_416282.png
# Les données décodées sont ['416282    http://foaming-indication.000webhostapp.com/vi...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\malicious_version_7_416283.png
# Les données décodées sont ['416283    http://filldata.s179.coreserver.jp/banana/cust...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\malicious_version_7_416284.png
# Les données décodées sont ['416284    https://verifikasi9021.wixsite.com/mysite\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\malicious_version_7_416285.png
# Les données décodées sont ['416285    http://bestchanke.org.ru/\nName: url, dtype: object']
# Liste des résultats : ['Suspect']
# Normal QR
# *****************************
# Multi-version QR codes dataset\qr_codes\malicious_version_7_416286.png
# Les données décodées sont ['416286    https://atrading.akid.website/wp-admin/css/col...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\malicious_version_7_416287.png
# Les données décodées sont ['416287    http://asiatechno.kz/admin/document/version/cl...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\malicious_version_7_416288.png
# Les données décodées sont ['416288    http://alterative-heater.000webhostapp.com/hom...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\malicious_version_7_416289.png
# Les données décodées sont ['416289    http://benandbear.com/ss/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\malicious_version_7_416290.png
# Les données décodées sont ['416290    https://nano.do/deduct-immensely-ding\nName: url, dtype: object']
# Liste des résultats : ['Suspect']
# Normal QR
# *****************************
# Multi-version QR codes dataset\qr_codes\malicious_version_7_416291.png
# Les données décodées sont ['416291    https://www.mailing027.gq/ib.absa.x/passcode_v...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\malicious_version_7_416292.png
# Les données décodées sont ['416292    https://secure.runescape.com-l.cz/m=weblogin/l...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\malicious_version_7_416293.png
# Les données décodées sont ['416293    https://serviceguru.in/interessa/HT65T/index.php\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\malicious_version_7_416294.png
# Les données décodées sont ['416294    https://review.cubicfrogapps.com/.well-known/a...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\malicious_version_7_416295.png
# Les données décodées sont ['416295    https://www.mailing027.cf/ib.absa/iAwIj4NCgkJC...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\malicious_version_7_416296.png
# Les données décodées sont ['416296    http://coreses.000webhostapp.com/scures.htm\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\malicious_version_7_416297.png
# Les données décodées sont ['416297    http://www.directregelen.org/abn%20amro/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\malicious_version_7_416298.png
# Les données décodées sont ['416298    http://www.mydocomo-smt-contact.com/\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\malicious_version_7_416299.png
# Les données décodées sont ['416299    https://abacubic.com/.logs/details/www.america...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\malicious_version_7_416300.png
# Les données décodées sont ['416300    https://umarbgs.com/support/b9e5569b4ac4e89ce9...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\malicious_version_7_416301.png
# Les données décodées sont ['416301    http://www.vub360.net/verify.htm\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\malicious_version_7_416302.png
# Les données décodées sont ['416302    http://bbva-movil-r.com/Cliente/Alertas/ES1394...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# *****************************
# Multi-version QR codes dataset\qr_codes\malicious_version_7_416303.png
# Les données décodées sont ['416303    http://thompsonsquare.ca/wp-includes/js/jquery...\nName: url, dtype: object']
# Liste des résultats : ['Frauduleux']
# Fraud
# Modèle sauvegardé dans q_learning_model.json
